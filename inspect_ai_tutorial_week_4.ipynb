# %% [markdown]
# # Tutorial 4: Evaluating LLM Agents on Mathematical Reasoning
#
# Welcome to the fourth tutorial in our AI Safety Evaluations course.
#
# So far you have evaluated models as **passive responders** — the model reads a prompt,
# produces an answer, and you score it. But many real-world AI systems are **agents**: they
# observe, reason, act (e.g. call a tool), observe the result, and repeat. Evaluating agents
# is harder because the model's behaviour is no longer a single forward pass — it is a
# *multi-step trajectory* where mistakes compound and new failure modes (infinite loops,
# tool misuse, hallucinated tool calls) appear.
#
# In this tutorial you will build and evaluate a simple **ReAct agent** that solves
# math problems by calling calculator and algebra tools. You will see first-hand how
# scaffolding choices — prompts, tool sets, message limits, output formatting — affect
# agent performance, and you will practice a basic dev/test workflow for iterating on
# an agent without overfitting to your evaluation set. Think of it as a toy,
# simplified version of a real elicitation pipeline like the
# [METR Elicitation Protocol](https://evaluations.metr.org/elicitation-protocol/).
#
# **What you'll learn:**
#
# - Define custom tools for inspect_ai agents
# - Build a ReAct agent and iteratively improve it on a dev set
# - Develop intuition for how scaffolding choices affect agent performance
#
# **By the end:** **You'll have a working agent evaluation pipeline and hands-on experience with the kind of iteration loop used in real-world agent evals.**

# %% [markdown]
# ## 1. Setup
#
# **Model choice.** We recommend picking a model that isn't too powerful — ideally one that occasionally
# stumbles on arithmetic so you can observe the effect of giving it tools. The examples
# below use `qwen2.5:3b`, but feel free to swap in any model you have access to (just make sure it supports tool calling). The
# main goal is to see how well the model uses the tools it's given, so don't worry if
# the tool-augmented score ends up lower than plain generation — that's a valid and
# interesting finding, not a sign that something is broken. Conversely, if your model
# solves everything perfectly even without tools, consider switching to a harder dataset
# (e.g. the full MATH instead of MATH-500, or a competition-math set like AIME) — just
# make sure to note this in your write-up.
#
# > **Resource note:** Agent evaluations generate many more LLM calls than simple Q&A evals
# > because each problem may involve multiple reasoning steps. All `eval()` calls in this
# > notebook use a `limit` parameter to cap the number of samples processed. Adjust
# > `EVAL_LIMIT` and `MAX_MESSAGES` if your machine is slow.

# %%
# !pip install sympy datasets scipy -q
print("✅ Installed: sympy, datasets, scipy")
import sympy as sp, datasets, scipy
print(sympy.__version__, datasets.__version__, scipy.__version__)
# Out:
# ✅ Installed: sympy, datasets, scipy
# 1.14.0 4.8.4 1.17.1

# %%
import re
import math
import random
from textwrap import dedent
from collections import defaultdict
from scipy.stats import norm

from inspect_ai import Task, eval
from inspect_ai.dataset import Sample, hf_dataset
from inspect_ai.agent import react
from inspect_ai.solver import generate, use_tools, system_message, TaskState
from inspect_ai.scorer import (
    Score, Target, model_graded_qa, scorer, accuracy, stderr, match, mean
)
from inspect_ai.tool import tool

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Configure model -- replace with what is available in your environment.
# E.g. 'ollama/qwen2.5:7b', 'openai/gpt-4o-mini', 'anthropic/claude-haiku-4-5'
# Must support tool calling (look for "tools" tag in Ollama).

MODEL = "openrouter/openai/gpt-oss-20b"

RANDOM_SEED = 42
EVAL_LIMIT = 30        # max samples per eval run (raise if your machine is fast)
MAX_MESSAGES = 20      # max back-and-forth messages per agent trajectory

# %% [markdown]
# A few helper functions for extracting and displaying results. You don't need to modify
# these — just run the cell and move on.

# %%
def get_acc(log):
    """Extract accuracy (or mean) from the first scorer in a log."""
    m = log.results.scores[0].metrics
    return (m.get("accuracy") or m.get("mean")).value


def _first_score(sample):
    """Get the first Score object from a sample, regardless of scorer name."""
    scores = sample.scores
    first_key = list(scores.keys())[0]
    val = scores[first_key]
    return val[0] if isinstance(val, list) else val


def print_results(label, log):
    """Pretty-print per-sample results from an eval log."""
    acc = get_acc(log)
    print(f"{'=' * 60}")
    print(f"  {label}   accuracy: {acc:.0%}")
    print(f"{'=' * 60}")
    for i, sample in enumerate(log.samples, 1):
        sc = _first_score(sample)
        msgs = len(sample.messages)
        expl = (sc.explanation or "")[:60]
        print(f"  [{sc.value}] #{i:2d}  msgs={msgs:2d}  "
              f"target={sample.target[:20]:>20s}  {expl}")
    print()

# %% [markdown]
# ## 2. Tools and Agent Architecture
#
# ### Why agents?
#
# A standard LLM evaluation looks like this: you hand the model a question, it produces
# an answer, and a scorer checks whether the answer is correct. The model has *one shot*.
#
# But many practical AI systems need to **interact with the world** — search the web, run
# code, query a database, or call an API — before they can answer. These systems are
# called **agents**. An agent follows a loop:
#
# 1. **Observe** the current state (the question, plus any tool outputs so far).
# 2. **Think** about what to do next.
# 3. **Act** by calling a tool (or submitting a final answer).
# 4. **Observe** the tool's result, then go back to step 2.
#
# This loop continues until the agent decides it has enough information to submit a final
# answer, or until a safety limit (maximum number of steps) is reached.
#
# ### Why not just give the model tools and let it figure things out?
#
# Because *access* to tools is not enough. The model also needs:
#
# - A **system prompt** that tells it what tools exist and how to use them
# - A **loop structure** that feeds tool results back so the model can reason about them
# - A **stopping criterion** so the model knows when and how to submit its final answer
# - **Message limits** to prevent runaway loops that burn tokens without progress
#
# This combination of prompt + loop + stopping logic is called **scaffolding**, and it
# can make or break agent performance. Whether an agent actually helps depends on the
# task, the tools, the prompt, and the model — scaffolding is not a guaranteed win, but
# understanding it is essential for evaluating agent systems.

# %% [markdown]
# ### Approaches to giving a model tools
#
# The simplest way to add tools in inspect_ai is the **`use_tools()` + `generate()`** pattern.
# `use_tools()` registers a list of tool functions so the model can call them, and
# `generate()` runs a **single generation**. The model may call tools during that generation,
# but the scaffolding never interrupts — tool calls and the final answer are produced in
# one continuous flow, with no structured pause to reconsider.
# ```python
# solver = [
#     system_message("You have access to calculator tools."),
#     use_tools([add(), multiply()]),
#     generate(),
# ]
# ```
#
# This is easy to set up but fragile: if a tool returns something unexpected mid-generation,
# the model is already committed to a line of reasoning and may not change course.
#
# ### The ReAct pattern
#
# **ReAct** (Reason + Act) is a scaffolding pattern that introduces an explicit pause after
# every tool call. The model reasons and calls one tool; the scaffolding then appends the
# result to the context and starts a **fresh generation** — so the model reconsiders its plan
# from scratch before deciding the next step. This closed feedback loop makes it much easier
# to recover from unexpected tool results or multi-step reasoning chains.
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                    ReAct Agent Loop                      │
# │                                                         │
# │   ┌──────────┐    ┌──────────┐    ┌──────────┐         │
# │   │  THINK   │───>│   ACT    │───>│ OBSERVE  │──┐      │
# │   │          │    │          │    │          │  │      │
# │   │ "I need  │    │ call     │    │ tool     │  │      │
# │   │  to add  │    │ add(a,b) │    │ returns  │  │      │
# │   │  these"  │    │          │    │ "111915" │  │      │
# │   └──────────┘    └──────────┘    └──────────┘  │      │
# │        ^                                        │      │
# │        └────────────────────────────────────────┘      │
# │                                                         │
# │   Loop continues until the agent calls submit()         │
# │   or the message limit is reached.                      │
# └─────────────────────────────────────────────────────────┘
# ```
#
# In **inspect_ai**, the `react()` solver implements this pattern. It:
# 1. Sends the problem with a system prompt describing available tools
# 2. Lets the model think and call one tool at a time
# 3. Appends the tool result to the context and starts a fresh generation
# 4. Repeats until the model calls `submit()` (a built-in action added automatically)
#
# The `submit()` tool is special — it signals the end of the loop and its argument
# becomes the agent's final answer. You never define `submit()` yourself; `react()`
# adds it for you.

# %% [markdown]
# ### Defining tools in inspect_ai
#
# An agent needs *actions* it can take in the world. In inspect_ai, actions are
# **tools** — Python functions the model can call during its reasoning loop.
#
# The `@tool` decorator registers a function so that inspect_ai can:
# 1. **Describe** it to the model (via the docstring and type hints — these become the
#    tool schema the model sees).
# 2. **Execute** it when the model emits a tool-call message and return the result.
#
# The pattern is a factory function (decorated with `@tool`) that returns an `async`
# inner function. The inner function's docstring and parameter annotations are what the
# model actually sees, so clear names and descriptions directly affect agent performance.
#
# Below we define four arithmetic tools ourselves. Notice how each one:
# - Takes typed parameters with descriptive `Args:` docstrings
# - Returns a **string** (tool outputs are always strings in inspect_ai)
# - Wraps execution in `try/except` so the agent gets a readable error instead of a crash
#
# > **Built-in tools:** inspect_ai also ships with ready-made tools for common agent tasks — you don't need to write these yourself:
# > - `bash()` — run shell commands
# > - `python()` — execute Python code
# > - `web_search()` — search the web
# > - `web_browser()` — full browser interaction
# > - `text_editor()` — read and edit files
# >
# > For the full list see the [Tools section of the inspect_ai documentation](https://inspect.ai-safety-institute.org.uk/tools.html).
# > In this tutorial we write our own tools from scratch to understand the mechanics,
# > but in practice you will often mix custom tools with these built-in ones.

# %%
@tool
def add():
    async def execute(a: float, b: float) -> str:
        """Add two numbers.

        Args:
            a: First number.
            b: Second number.
        """
        try:
            return str(float(a) + float(b))
        except Exception as e:
            return f"Error: {e}"
    return execute


@tool
def subtract():
    async def execute(a: float, b: float) -> str:
        """Subtract b from a.

        Args:
            a: Number to subtract from.
            b: Number to subtract.
        """
        try:
            return str(float(a) - float(b))
        except Exception as e:
            return f"Error: {e}"
    return execute


@tool
def multiply():
    async def execute(a: float, b: float) -> str:
        """Multiply two numbers.

        Args:
            a: First number.
            b: Second number.
        """
        try:
            return str(float(a) * float(b))
        except Exception as e:
            return f"Error: {e}"
    return execute


@tool
def divide():
    async def execute(a: float, b: float) -> str:
        """Divide a by b.

        Args:
            a: Dividend.
            b: Divisor (must not be zero).
        """
        try:
            b_val = float(b)
            if b_val == 0:
                return "Error: division by zero."
            return str(float(a) / b_val)
        except Exception as e:
            return f"Error: {e}"
    return execute

# %% [markdown]
# ## Assignment 1: Create a `modular_arithmetic` tool
#
# Cryptography and number theory problems often require modular arithmetic —
# for example, computing $7^{1000} \mod 13$ as part of a larger proof.
#
# Following the pattern above, implement a `modular_arithmetic` tool with a clear docstring.

# %%
@tool
def modular_arithmetic():
    async def execute(a: int, b: int) -> str:
        """Compute a mod b.
        
        Args:
            a: The number to divide.
            b: The modulus (must not be zero).
        """
        try:
            b_val = int(b)
            if b_val == 0:
                return "Error: modulus by zero."
            return str(int(a) % b_val)
        except Exception as e:
            return f"Error: {e}"
    return execute

# %% [markdown]
# Now let's see the tool in action. We run a small eval so the model attempts to use your tool. Don't worry if the model gets the answer wrong — what matters here is that the tool itself is correctly defined.

# %%
_test_samples_mod = [
    Sample(input="What is 1000000 mod 397? Reply with just the number.", target="354"),
    Sample(input="What is 100 mod 10? Reply with just the number.", target="0"),
]

_log_mod_test = eval(
    Task(
        dataset=_test_samples_mod,
        solver=react(
            prompt=(
                "You have a modular_arithmetic(a, b) tool. "
                "Use modular_arithmetic(a, b) to compute the answer if needed."
                "Then call submit(answer=<number>). "
                "Do not invent tool names."
            ),
            tools=[modular_arithmetic()],
            attempts=1,
        ),
        scorer=match(numeric=True),
        message_limit=10,
    ),
    model=MODEL,
)[0]

print_results("modular_arithmetic tool test", _log_mod_test)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   modular_arithmetic tool test   accuracy: 100%
# ============================================================
#   [C] # 1  msgs= 5  target=                 354  354
#   [C] # 2  msgs= 5  target=                   0  0

# %% [markdown]
# > **Checking tool usage.** Run **`inspect view`** in the terminal to see the full
# > message trace for each sample — tool calls and their responses appear as explicit
# > steps. Alternatively, inspect `log.samples[i].messages` directly: each tool
# > call appears as a message with `role="assistant"` and a non-empty **`tool_calls`** field.

# %% [markdown]
# ---
# 1. Did the model actually *use* your tool, or did it answer without using it?
#    Open the eval log in the inspect_ai viewer (`inspect view`) and check the trace —
#    you should see explicit tool call steps between the initial question and the final answer.
# 2. If the model skipped the tool, adjust the prompt in the `react()` call above and
#    re-run until the model uses it. What did you change?
#
# **Your answer:**
#
# 1. Да, модель вызвала тул в обоих вопросах. Но при первом запуске запуталась  вызовом встроенного тула submit(), пытаясь сделать что-то такое: `submit<|channel|>commentary(answer: "0")`.
# 2. Усилил промпт, описав в том числе и submit tool. Справилась отлично.

# %%
ARITH_TOOLS = [add(), subtract(), multiply(), divide(), modular_arithmetic()]

# %% [markdown]
# ## 3. Toy Evaluation — Three Solver Architectures
#
# Before touching a real benchmark, let's try out three different solver architectures
# on a small set of hand-crafted problems. These 12 word problems use numbers large
# enough that a model without tools might make arithmetic errors.
#
# We will compare three solver architectures:
#
# - **Plain generation** - reads the question, produces an answer in one shot;
#   solver: `generate()`
# - **Naive tool loop** - gets access to tools; `generate()` runs once and may call
#   some tools; solver: `use_tools()` + `generate()`
# - **ReAct agent** - explicit think-act-observe loop with a `submit()` action to stop;
#   solver: `react()`
#
# The goal here is to see how each architecture behaves — both in terms of accuracy
# and how the solver actually runs — before moving to a real benchmark.

# %%
TOY_SAMPLES = [
    Sample(
        input=(
            "A semiconductor factory produced 48,397 chips on Monday "
            "and 63,518 chips on Tuesday. How many chips were produced in total?"
        ),
        target="111915",
    ),
    Sample(
        input=(
            "A government reserve had 874,203 barrels of oil. "
            "After an emergency release, 295,867 barrels were distributed. "
            "How many barrels remain in the reserve?"
        ),
        target="578336",
    ),
    Sample(
        input=(
            "A logistics company ships 4,738 containers, each holding 2,659 units. "
            "How many units are shipped in total?"
        ),
        target="12598342",
    ),
    Sample(
        input=(
            "A national census counted 8,743,291 residents across 6,473 districts. "
            "If residents are distributed equally, how many full residents "
            "are assigned per district?"
        ),
        target="1350",
    ),
    Sample(
        input=(
            "A satellite completes a full orbit every 397 minutes. "
            "After exactly 1,000,000 minutes of operation, how many minutes "
            "have passed since the last complete orbit?"
        ),
        target="354",
    ),
    Sample(
        input=(
            "A hospital ordered 12,475 boxes of supplies at 387 dollars per box. "
            "They received a bulk discount of 843,750 dollars off the total. "
            "How much did the hospital pay after the discount?"
        ),
        target="3984075",
    ),
    Sample(
        input=(
            "A city has 14 times as many residents as municipal employees. "
            "If the total number of residents and employees together is 489,375, "
            "how many municipal employees does the city have?"
        ),
        target="32625",
    ),
    Sample(
        input=(
            "An airline flew 3,847 domestic flights and 2,964 international flights "
            "last month. Each flight used an average of 8,753 liters of fuel. "
            "How many liters of fuel were used in total?"
        ),
        target="59616683",
    ),
    Sample(
        input=(
            "A clock tower rings a bell every 1,873 seconds. "
            "After 10,000,000 seconds have elapsed since midnight, "
            "how many seconds ago did the bell last ring?"
        ),
        target="53",
    ),
    Sample(
        input=(
            "A farm harvested 247,839 kg of wheat and 184,672 kg of barley. "
            "The grain is loaded into trucks that carry exactly 4,750 kg each. "
            "How many full truckloads can be made from all the grain?"
        ),
        target="91",
    ),
    Sample(
        input=(
            "A global streaming platform has 1,847,293,847,291 seconds of video content. "
            "Given that a day has 86,400 seconds, how many full days of content "
            "does the platform have?"
        ),
        target="21380715",
    ),
    Sample(
        input=(
            "A country's economy grew by 3,847 dollars per citizen in a year. "
            "The country has 847,293,847 citizens. "
            "What was the total economic growth in dollars?"
        ),
        target="3259539429409",
    ),
]

# %% [markdown]
# ## 3a. Approach 0: Plain generation (no tools)
#
# The simplest baseline: give the model a system prompt and ask it to solve the problem
# directly. The solver is just `generate()` — a single forward pass with no tool access.
#
# We score with `match(numeric=True)`, which extracts the first number from the model's
# response and compares it to the target.

# %%
SIMPLE_PROMPT = dedent("""    You are a math solver. Read the problem carefully, compute the answer,
    and respond with the final numeric result.
""")

log_toy_gen = eval(
    Task(
        dataset=TOY_SAMPLES,
        solver=[system_message(SIMPLE_PROMPT), generate()],
        scorer=match(numeric=True),
    ),
    model=MODEL,
)[0]

print_results("Approach 0: generate() only", log_toy_gen)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Approach 0: generate() only   accuracy: 83%
# ============================================================
#   [C] # 1  msgs= 3  target=              111915  111,915
#   [C] # 2  msgs= 3  target=              578336  578,336 barrels.
#   [C] # 3  msgs= 3  target=            12598342  12,598,342
#   [C] # 4  msgs= 3  target=                1350  1,350
#   [C] # 5  msgs= 3  target=                 354  A full orbit takes \(397\) minutes.
# After \(1{,}000{,}000\
#   [I] # 6  msgs= 3  target=             3984075  The total cost before discount is
# \(12\,475 \times 387 = 4
#   [C] # 7  msgs= 3  target=               32625  32,625 municipal employees.
#   [I] # 8  msgs= 3  target=            59616683  The airline operated
#
# \(3{,}847 + 2{,}964 = 6{,}811\) flig
#   [C] # 9  msgs= 3  target=                  53  53
#   [C] #10  msgs= 3  target=                  91  To determine the number of full truckloads, first find the t
#   [C] #11  msgs= 3  target=            21380715  21,380,715 days
#   [C] #12  msgs= 3  target=       3259539429409  3259539429409

# %% [markdown]
# ---
# 1. Did the model get everything right, or did it make arithmetic errors on the larger numbers?
# 2. If there were errors, what do you think caused them?
#
# **Your answer:**
# 1. К сожалению да, нужно было брать модельку ещё попроще, OSS-20B уже хорошо считает, плюс это ризонер сам по себе.
# 2. Если посмотреть на лог прогона, то там проблемы с форматом выдачи, а не расчетами, они верные.

# %% [markdown]
# ## 3b. Approach A: Naive tool loop
#
# Now we give the model access to our arithmetic tools via `use_tools()`, followed by a
# single `generate()`. The model *can* call tools, but the solver doesn't enforce any
# structure: it may call one tool, multiple tools, or none at all, and it generates a
# final answer in the same pass.
#
# > In practice this pattern is rarely used on its own — without scaffolding, whether the
# > model actually uses the tools is largely unpredictable.

# %%
NAIVE_LOOP_PROMPT = dedent("""    You are a math solver with access to calculator tools.
    Break each problem into arithmetic steps and call one tool per step.
""")

log_toy_naive = eval(
    Task(
        dataset=TOY_SAMPLES,
        solver=[
            system_message(NAIVE_LOOP_PROMPT),
            use_tools(ARITH_TOOLS),
            generate(),
        ],
        scorer=match(numeric=True),
    ),
    model=MODEL,
)[0]

print_results("Approach A: use_tools + generate (naive loop)", log_toy_naive)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Approach A: use_tools + generate (naive loop)   accuracy: 67%
# ============================================================
#   [I] # 1  msgs= 5  target=              111915  The total number of chips produced over the two days is
#
# \
#   [I] # 2  msgs= 5  target=              578336  The remaining barrels in the reserve are \(874{,}203 - 295{,
#   [C] # 3  msgs= 5  target=            12598342  The total number of units shipped is
#
# \[
# 4\,738 \times 2\,
#   [C] # 4  msgs= 5  target=                1350  1,350 residents per district.
#   [C] # 5  msgs= 5  target=                 354  354
#   [C] # 6  msgs= 7  target=             3984075  The cost before the discount was:
#
# \[
# 12,475 \times 387 = 4,
#   [C] # 7  msgs= 5  target=               32625  Let \(E\) be the number of municipal employees.
#
# The number
#   [I] # 8  msgs= 5  target=            59616683  The total number of flights was
#
# \(3,847 + 2,964 = 6,811\)
#   [C] # 9  msgs= 5  target=                  53  First compute how far 10,000,000 seconds is beyond a multipl
#   [C] #10  msgs= 7  target=                  91  First sum the two amounts of grain:
#
# \(247\,839\text{ kg} +
#   [I] #11  msgs= 5  target=            21380715  To determine how many **full days** of content the platform
#   [C] #12  msgs= 5  target=       3259539429409  The total economic growth is
#
# \[
# 3\,847 \text{ dollars/per

# %% [markdown]
# ---
# 1. Did having access to tools improve results compared to the baseline?
# 2. Did the model actually use the tools, or did it ignore them?
#
# **Your answer:**
#
# 1. Что интересно, нет. Опять проблема формата.
# 2. Да, юзала и активно.

# %% [markdown]
# ## 3c. Approach B: ReAct agent
#
# Now let's use the `react()` solver — the full ReAct loop described in the introduction.
# Notice the prompt explicitly tells the model to use tools and call `submit()` at the end.

# %%
REACT_PROMPT_V1 = dedent("""    You are a math solver with access to calculator tools.
    Break each problem into arithmetic steps and call one tool per step.
    Don't calculate anything without tools.
    After getting the final numeric result, call submit() with ONLY the number.
""")

log_toy_react = eval(
    Task(
        dataset=TOY_SAMPLES,
        solver=react(prompt=REACT_PROMPT_V1, tools=ARITH_TOOLS, attempts=1),
        scorer=match(numeric=True),
        message_limit=20,
    ),
    model=MODEL,
)[0]

print_results("Approach B: react() with simple prompt", log_toy_react)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Approach B: react() with simple prompt   accuracy: 100%
# ============================================================
#   [C] # 1  msgs= 5  target=              111915  111915
#   [C] # 2  msgs= 5  target=              578336  578336
#   [C] # 3  msgs= 5  target=            12598342  12598342
#   [C] # 4  msgs= 5  target=                1350  1350
#   [C] # 5  msgs= 5  target=                 354  354
#   [C] # 6  msgs= 7  target=             3984075  3984075
#   [C] # 7  msgs= 5  target=               32625  32625
#   [C] # 8  msgs= 5  target=            59616683  59616683
#   [C] # 9  msgs= 5  target=                  53  53
#   [C] #10  msgs= 7  target=                  91  91
#   [C] #11  msgs= 7  target=            21380715  21380715
#   [C] #12  msgs= 5  target=       3259539429409  3259539429409

# %% [markdown]
# ## Comparing the three approaches
#
# Let's see the results side by side. Pay attention not just to accuracy but also to the
# number of messages — more messages means more LLM calls, which means more cost and latency.

# %%
TOY_LOGS = [log_toy_gen, log_toy_naive, log_toy_react]
TOY_LABELS = ["generate only", "naive tool loop", "react v1"]

print(f"{'Approach':<25s} {'Acc':>5s}  {'Avg msgs':>8s}  {'Max msgs':>8s}")
print("-" * 50)
for label, log in zip(TOY_LABELS, TOY_LOGS):
    acc = get_acc(log)
    msg_list = [len(s.messages) for s in log.samples]
    avg_m = sum(msg_list) / len(msg_list)
    max_m = max(msg_list)
    print(f"{label:<25s} {acc:>4.0%}   {avg_m:>7.1f}   {max_m:>7d}")
# Out:
# Approach                    Acc  Avg msgs  Max msgs
# --------------------------------------------------
# generate only              83%       3.0         3
# naive tool loop            67%       5.3         7
# react v1                  100%       5.5         7

# %% [markdown]
# ---
# 1. Which approach performed best? Was it also the most expensive (most messages)?
# 2. Open the eval and compare the naive tool loop and the ReAct
#    agent traces. Did the model actually use the tools in both cases, and how does the
#    structure of the traces differ?
#
# **Your answer:**
#
# 1. Лучше всех себя показал ReAct. И да, он был наиболее дорогим по среднему числу сообщений (хотя naive почти такой же). Правда в нашем кейсе, повторюсь, модель достаточно хороша и хватило бы только указания формата ответа в промпте.
# 2.  В нашем кейсе с нашей моделью получилось что различия в трейсах не большие. Кроме того, что в ReAct модель аккуратно подает данные в submit и нет никаких проблем вызванных неверным форматом и парсингом ответа.

# %% [markdown]
# ## 4. Adding a Symbolic Algebra Tool
#
# Arithmetic tools help with computation, but many math problems require solving
# equations — "find x such that 3x + 7 = 22". A small model can't do this reliably
# without tools, but SymPy (a Python symbolic math library) can solve it exactly.
#
# ## Assignment 2: Create the `sympy_solve` tool
#
# Implement a tool that takes an equation string (e.g. `"2*x + 5 = 21"` or `"3*x**2 - 12 = 0"`)
# and returns the solutions using SymPy. The tool should:
#
# 1. Parse the equation — if it contains `=`, split into left and right sides and solve `left - right = 0`
# 2. If there's no `=`, treat the input as an expression equal to zero
# 3. Solve for the symbol `x`
# 4. Return the solutions as a string, or `"No solution found."` if empty
# 5. Handle errors gracefully

# %%
@tool
def sympy_solve():
    async def execute(equation: str) -> str:
        """Solve an equation for x using SymPy.

        Args:
            equation: An equation or expression as a string. If it contains "=",
                the tool solves left - right = 0. If there is no "=",
                the expression is treated as equal to zero.
        """
        try:
            x = sp.Symbol("x")

            if "=" in equation:
                left_str, right_str = equation.split("=", 1)
                left_expr = sp.sympify(left_str.strip(), locals={"x": x})
                right_expr = sp.sympify(right_str.strip(), locals={"x": x})
                expr = left_expr - right_expr
            else:
                expr = sp.sympify(equation.strip(), locals={"x": x})

            solutions = sp.solve(expr, x)

            if not solutions:
                return "No solution found."

            return str(solutions)

        except Exception as e:
            return f"Error: {e}"
    return execute

# %%
# Run the eval — the model should use your tool to solve both equations.
_log_sympy_test = eval(
    Task(
        dataset=[
            Sample(
                input="Solve for x: 2*x + 5 = 21. Reply with just the number.",
                target="8",
            ),
            Sample(
                input="Solve for x: x**2 - 9 = 0. What are the solutions? Reply with just the numbers separated by comma.",
                target="-3, 3",
            ),
        ],
        solver=react(
            prompt="You have a sympy_solve(equation) tool. Use it to solve the equation, then submit the result.",
            tools=[sympy_solve()],
            attempts=1,
        ),
        scorer=match(numeric=True),
        message_limit=10,
    ),
    model=MODEL,
)[0]

print_results("sympy_solve tool test", _log_sympy_test)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   sympy_solve tool test   accuracy: 100%
# ============================================================
#   [C] # 1  msgs= 5  target=                   8  8
#   [C] # 2  msgs= 5  target=               -3, 3  -3, 3

# %% [markdown]
# ---
# 1. Did the model use the `sympy_solve` tool, or did it try to solve the equations
#    in its head? (Check the message counts.)
# 2. If it didn't use the tool, try adjusting the prompt in the `react()` call.
#    What wording helped?
#
# **Your answer:**
#
# 1. Вызывает. Хотя вообще решает сначала сама, а потом вспоминает что есть тул и дёргает его.
# 2. Не было проблем, так что не пробовал

# %%
# Bundle all tools
ARITH_TOOLS = [add(), subtract(), multiply(), divide(), modular_arithmetic()]
ALL_TOOLS = ARITH_TOOLS + [sympy_solve()]

# %% [markdown]
# ## 5. Loading the MATH-500 Benchmark
#
# Now that we have a working agent with tools, let's evaluate it on a real benchmark.
# **MATH-500** is a 500-question subset of the MATH dataset (Hendrycks et al., 2021),
# covering competition-level math across seven subjects. It's available on Hugging Face.
#
# Not all subjects benefit equally from our tools — Geometry and Counting & Probability
# involve spatial reasoning and combinatorics that our calculator tools can't help with.
# We'll focus on the four subjects where arithmetic and algebra tools are most relevant:
# Algebra, Intermediate Algebra, Number Theory, and Prealgebra.
#
# ### Extracting answers from MATH solutions
#
# MATH stores answers inside `\boxed{...}` in the solution string. We need a helper to
# extract them:

# %%
TOOL_SUBJECTS = [
    "Algebra", "Number Theory", "Prealgebra", "Intermediate Algebra",
]


def extract_boxed(solution):
    """Extract the content of the last \\boxed{...} in a MATH solution string."""
    idx = solution.rfind("\\boxed{")
    if idx == -1:
        return solution.strip()
    start = idx + len("\\boxed{")
    depth = 1
    i = start
    while i < len(solution) and depth > 0:
        if solution[i] == "{":
            depth += 1
        elif solution[i] == "}":
            depth -= 1
        i += 1
    return solution[start:i - 1].strip()


def record_to_sample(record):
    """Convert a MATH-500 record into an inspect_ai Sample."""
    target = record.get("answer") or extract_boxed(record["solution"])
    return Sample(
        input=record["problem"],
        target=target,
        metadata={
            "level": int(record["level"]),
            "subject": record["subject"],
        },
    )

# %%
full_dataset = hf_dataset(
    path="HuggingFaceH4/MATH-500",
    split="test",
    sample_fields=record_to_sample,
    cached=True,
)

print(f"Total MATH-500: {len(full_dataset)} samples")

subject_counts = defaultdict(int)
for s in full_dataset:
    subject_counts[s.metadata["subject"]] += 1

print(f"\n{'Subject':<30s} {'Count':>5s}")
print("-" * 37)
for subj in sorted(subject_counts):
    marker = " <-- tool-friendly" if subj in TOOL_SUBJECTS else ""
    print(f"{subj:<30s} {subject_counts[subj]:>5d}{marker}")
# Out:
# Loading dataset HuggingFaceH4/MATH-500 from Hugging Face...
# README.md:   0%|          | 0.00/412 [00:00<?, ?B/s]
# d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\huggingface_hub\file_download.py:129: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\yuri.zinyakov\.cache\huggingface\hub\datasets--HuggingFaceH4--MATH-500. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# test.jsonl: 0.00B [00:00, ?B/s]
# Generating test split:   0%|          | 0/500 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/500 [00:00<?, ? examples/s]
# Total MATH-500: 500 samples
#
# Subject                        Count
# -------------------------------------
# Algebra                          124 <-- tool-friendly
# Counting & Probability            38
# Geometry                          41
# Intermediate Algebra              97 <-- tool-friendly
# Number Theory                     62 <-- tool-friendly
# Prealgebra                        82 <-- tool-friendly
# Precalculus                       56

# %% [markdown]
# ## Dev/test split
#
# A core principle in evaluation: **never tune on your test set.** Iterating on the same
# data you use for final scoring inflates results and makes them meaningless. We split the
# tool-friendly subset into a small **dev set** (10%) for prompt and scaffolding iteration,
# and a larger **test set** (90%) reserved for final evaluation only.
#
# This mirrors the elicitation workflow described in [METR's Guidelines for Capability Elicitation](https://evaluations.metr.org/elicitation-protocol/): iterate against the dev set until failures stabilize, then run the test set once.
#
# > **Adjust to your hardware.** If even the dev set takes too long, reduce `split_point`
# > or set a smaller `EVAL_LIMIT`. The point is rapid iteration — you can always increase
# > the test set size later.

# %%
tool_dataset = [s for s in full_dataset if s.metadata["subject"] in TOOL_SUBJECTS]
print(f"Tool-friendly subset: {len(tool_dataset)} samples")

random.seed(RANDOM_SEED)
random.shuffle(tool_dataset)

split_point = int(len(tool_dataset) * 0.1)
DEV_SET = tool_dataset[:split_point]
TEST_SET = tool_dataset[split_point:]

print(f"DEV_SET:  {len(DEV_SET)} samples")
print(f"TEST_SET: {len(TEST_SET)} samples")
# Out:
# Tool-friendly subset: 365 samples
# DEV_SET:  36 samples
# TEST_SET: 329 samples

# %%
DEV_SET[0]
# Out:
# Sample(input='Solve\n\\[\\sqrt{x + \\sqrt{3x + 6}} + \\sqrt{x - \\sqrt{3x + 6}} = 6.\\]', choices=None, target='10', id=None, metadata={'level': 3, 'subject': 'Intermediate Algebra'}, sandbox=None, files=None, setup=None)

# %% [markdown]
# ## 6. Scoring Mathematical Answers
#
# For the toy problems we used `match(numeric=True)`, which works when answers are plain
# numbers. But MATH answers can be fractions (`3/7`), expressions (`2\sqrt{5}`), or
# formatted in different equivalent ways — a simple string match will miss many correct answers.
#
# We covered `model_graded_qa()` in notebook 3. Here we apply it to math: the key challenge
# is writing a grading prompt that handles equivalent notations (e.g. `1/2` vs `0.5` vs `\frac{1}{2}`).
# Note that in notebook 3 we deliberately hid the reference answer from the grading model — here
# there's no reason to do that, so you can pass the correct answer directly.
#
# > **Trade-off:** Model-graded scoring is slower and noisier, but catches equivalences that
# > string matching misses. For production evals you might want a more capable model for
# > grading than the one being tested — think about what makes sense for your setup.
#
# ## Assignment 3: Define the math scorer
#
# Define a `math_scorer` using `model_graded_qa()`. Write a grading prompt that instructs
# the model to judge mathematical equivalence and respond with **C** (correct) or **I** (incorrect),
# and choose which model should do the grading. Think about what edge cases matter: different
# notations, equivalent fractions, simplified vs unsimplified forms.

# %%
SCORER_MODEL = MODEL # Для нашего примера используем тот же модель для оценки, но в реальной оценке можно использовать более мощную модель-оценщика.

GRADING_INSTRUCTIONS = """
You are grading a mathematical answer.

Decide whether the model's answer is mathematically equivalent to the reference answer.

Mark as correct (C) if the answer is mathematically the same, even if written differently.
Examples of equivalent answers:
- fractions and decimals: 1/2 = 0.5 = \\frac{1}{2}
- simplified vs unsimplified forms: 2/4 = 1/2
- algebraically equivalent expressions
- different but equivalent mathematical notation

Mark as incorrect (I) if:
- the mathematical value is different
- the answer is incomplete
- the answer gives extra incorrect solutions
- the answer is only an approximation when an exact answer is expected
- the answer uses a different variable or object than required

Be strict about mathematical equivalence, but ignore harmless formatting differences.

Reply with exactly one line:
GRADE: C
or
GRADE: I
"""

MATH_SCORER = model_graded_qa(
    instructions=GRADING_INSTRUCTIONS,
    model=SCORER_MODEL,
)

# %%
# Run the scorer on two toy samples where we know the answer.
_scorer_test_samples = [
    Sample(input="What is 1+1?", target="2"),
    Sample(input="What is 10/4?", target="5/2"),
]

_log_scorer_test = eval(
    Task(
        dataset=_scorer_test_samples,
        solver=[system_message("Answer the math question. Reply with just the answer."), generate()],
        scorer=MATH_SCORER,
    ),
    model=MODEL,
)[0]

print_results("Scorer sanity check", _log_scorer_test)
print("Check: does the scorer correctly mark equivalent answers as C?")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Scorer sanity check   accuracy: 100%
# ============================================================
#   [C] # 1  msgs= 3  target=                   2  GRADE: C
#   [C] # 2  msgs= 3  target=                 5/2  GRADE: C
#
# Check: does the scorer correctly mark equivalent answers as C?

# %% [markdown]
# ---
# 1. Did your scorer correctly handle the fraction equivalence (`10/4` vs `5/2`)?
# 2. What failure modes can you imagine for model-graded scoring?
#
# **Your answer:**
#
# 1. Да.
# 2. В принципе все те, что анализировали на прошлой неделе. Плюс ещё специфичные для математики, например:
# * не верно оценить математическую эквивалентность, если форма записи сильно отличается
# * принять приближенный ответ
# * запутаться в объяснениях и неверно понять ответ

# %% [markdown]
# ## 7. Dev-Set Iteration — Building and Improving Your Agent
#
# This is the core of agent evaluation: run on the dev set, see where the agent struggles,
# and systematically improve it. The iteration loop:
#
# 1. Run the current agent on the dev set
# 2. Inspect failures — *why* did the agent get these wrong?
# 3. Hypothesize an improvement (better prompt? more tools? output formatting?) — and check
#    whether the answer was actually correct but the scorer marked it wrong
# 4. Implement the change and re-evaluate on the dev set
# 5. Repeat

# %% [markdown]
# ## Assignment 4: Build and improve a ReAct agent
#
# Your goal is to build a ReAct agent and iterate on it using the dev set.
# Does adding tools and scaffolding help on this task, and by how much?
# Start by running a basic ReAct agent on the dev set, then look at the failures in the logs and iterate.
#
# **Step 1 — Run a baseline.** Write a system prompt and run `react()` with `ALL_TOOLS` on the dev set.
#
# **Step 2 — Inspect failures.** Open the logs and look at what went wrong. Common things to consider:
# - Is the model ignoring tools and is failing?
# - Is the answer mathematically correct but formatted wrong (e.g. `0.5` instead of `1/2`)?
# - Is the model getting lost in multi-step problems?
#
# **Step 3 — Iterate.** Based on what you see, try to improve. Some directions:
# - Make the system prompt more explicit about strategy or answer format
# - Add tools that cover operations the model struggles with (e.g. a single `calculator` tool, `gcd`, `factorial` or something very different)
# - Add a format-extraction step after the `react()` loop if formatting is the main issue
# - Reconsider the scorer if correct answers are being marked wrong
#
# For each configuration you try, store the result as a `(description, log)` tuple in `DEV_RUNS` at the bottom — this will let you compare all your attempts in one table. Try at least two configurations.

# %%
MY_REACT_PROMPT = """
You are a math problem-solving agent.

Solve the problem step by step.
Use the available tools when they are helpful, especially for arithmetic, modular arithmetic, or solving equations.
If a tool is useful, call it instead of doing the calculation entirely in your head.

When you are ready, submit only the final mathematical answer.
Do not include explanation in the final submitted answer.
"""

log_attempt_1 = eval(
    Task(
        dataset=DEV_SET,
        solver=react(
            prompt=MY_REACT_PROMPT,
            tools=ALL_TOOLS,
            attempts=1,
        ),
        scorer=MATH_SCORER,
        message_limit=MAX_MESSAGES,
    ),
    model=MODEL,
    limit=EVAL_LIMIT,
)[0]

print_results("Attempt 1 (baseline)", log_attempt_1)
DEV_RUNS = [("Attempt 1 (baseline)", log_attempt_1)]
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Attempt 1 (baseline)   accuracy: 97%
# ============================================================
#   [C] # 1  msgs= 3  target=                  10  GRADE: C
#   [C] # 2  msgs= 5  target=                  47  GRADE: C
#   [C] # 3  msgs= 5  target=                2k+2  GRADE: C
#   [C] # 4  msgs= 3  target=                   2  GRADE: C
#   [C] # 5  msgs= 3  target=                   5  GRADE: C
#   [C] # 6  msgs= 5  target=          (a+5)(b+2)  GRADE: C
#   [C] # 7  msgs= 9  target=                 550  GRADE: C
#   [C] # 8  msgs= 3  target=                   2  GRADE: C
#   [C] # 9  msgs= 3  target=                   0  GRADE: C
#   [C] #10  msgs= 3  target=                   1  GRADE: C
#   [C] #11  msgs= 3  target=                   3  GRADE: C
#   [C] #12  msgs= 7  target=         \frac{3}{2}  GRADE: C
#   [I] #13  msgs= 5  target=                   1  GRADE: I
#   [C] #14  msgs= 3  target=                   4  GRADE: C
#   [C] #15  msgs= 3  target=                  14  GRADE: C
#   [C] #16  msgs= 3  target=               26000  GRADE: C
#   [C] #17  msgs= 5  target=          \$32,\!348  GRADE: C
#   [C] #18  msgs= 3  target=                  13  GRADE: C
#   [C] #19  msgs= 3  target=                  24  GRADE: C
#   [C] #20  msgs= 5  target=                  64  GRADE: C
#   [C] #21  msgs= 3  target=                   2  GRADE: C
#   [C] #22  msgs= 3  target=            36^\circ  GRADE: C
#   [C] #23  msgs= 5  target=        \frac{13}{4}  GRADE: C
#   [C] #24  msgs= 5  target=                4005  GRADE: C
#   [C] #25  msgs= 3  target=                   4  GRADE: C
#   [C] #26  msgs= 5  target=                 120  GRADE: C
#   [C] #27  msgs= 3  target=              4343_6  GRADE: C
#   [C] #28  msgs= 5  target=       \frac{17}{21}  GRADE: C
#   [C] #29  msgs= 3  target=                  36  GRADE: C
#   [C] #30  msgs= 3  target=                   6  GRADE: C

# %% [markdown]
# Ладно, стоило давно сменить модель, так не интересно. Недооценил GPT-OSS-20B. Оставим её для скоринга, а в качестве основной модели агента используем llama-3.1-8b-instruct.

# %%
SMALL_MODEL = "openrouter/meta-llama/llama-3.1-8b-instruct"

# %%
MY_REACT_PROMPT = """
You are a math problem-solving agent.

Solve the problem step by step.
Use the available tools when they are helpful, especially for arithmetic, modular arithmetic, or solving equations.
If a tool is useful, call it instead of doing the calculation entirely in your head.

When you are ready, submit only the final mathematical answer.
Do not include explanation in the final submitted answer.
"""

log_attempt_1 = eval(
    Task(
        dataset=DEV_SET,
        solver=react(
            prompt=MY_REACT_PROMPT,
            tools=ALL_TOOLS,
            attempts=1,
        ),
        scorer=MATH_SCORER,
        message_limit=MAX_MESSAGES,
    ),
    model=SMALL_MODEL,
    limit=EVAL_LIMIT,
    attempt_timeout=180,
    max_retries=3
)[0]

print_results("Attempt 1 (llama-3.1-8b-instruct)", log_attempt_1)
DEV_RUNS.append(("Attempt 1 (llama-3.1-8b-instruct)", log_attempt_1))
# Out:
# Output()
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '180' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '180' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '180' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '180' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '180' exceeded.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Attempt 1 (llama-3.1-8b-instruct)   accuracy: 20%
# ============================================================
#   [I] # 1  msgs= 4  target=                  10  GRADE: I
#   [I] # 2  msgs=15  target=                  47  GRADE: I
#   [C] # 3  msgs= 9  target=                2k+2  GRADE: C
#   [I] # 4  msgs=11  target=                   2  GRADE: I
#   [I] # 5  msgs= 6  target=                   5  GRADE: I
#   [C] # 6  msgs= 6  target=          (a+5)(b+2)  GRADE: C
#   [C] # 7  msgs=11  target=                 550  GRADE: C
#   [I] # 8  msgs= 6  target=                   2  GRADE: I
#   [C] # 9  msgs= 7  target=                   0  GRADE: C
#   [I] #10  msgs=10  target=                   1  GRADE: I
#   [I] #11  msgs=15  target=                   3  GRADE: I
#   [C] #12  msgs= 5  target=         \frac{3}{2}  GRADE: C
#   [I] #13  msgs=13  target=                   1  GRADE: I
#   [I] #14  msgs=20  target=                   4  GRADE: I
#   [I] #15  msgs=18  target=                  14  GRADE: I
#   [I] #16  msgs= 6  target=               26000  GRADE: I
#   [I] #17  msgs= 8  target=          \$32,\!348  GRADE: I
#   [I] #18  msgs= 7  target=                  13  GRADE: I
#   [C] #19  msgs= 9  target=                  24  GRADE: C
#   [I] #20  msgs= 6  target=                  64  GRADE: I
#   [I] #21  msgs= 5  target=                   2  GRADE: I
#   [I] #22  msgs= 7  target=            36^\circ  GRADE: I
#   [I] #23  msgs=11  target=        \frac{13}{4}  GRADE: I
#   [I] #24  msgs= 7  target=                4005  GRADE: I
#   [I] #25  msgs=18  target=                   4  GRADE: I
#   [I] #26  msgs= 6  target=                 120  GRADE: I
#   [I] #27  msgs=10  target=              4343_6  GRADE: I
#   [I] #28  msgs= 8  target=       \frac{17}{21}  GRADE: I
#   [I] #29  msgs= 7  target=                  36  GRADE: I
#   [I] #30  msgs=10  target=                   6  GRADE: I

# %% [markdown]
# Теперь всё гораздо лучше, ну то есть хуже. Модель редко корректно юзает инструменты, иногда зацикливается, в общем показывает себя довольно слабо в нашем базовой agent-сетапе.

# %%
# Look at the failures in the logs and decide what to change:
# prompt, tools, scorer, add a format-extraction step after react() or something else.
# Duplicate this cell for each new configuration. Give each log a new name.

# YOUR CODE HERE: define your updated prompt, tools, scorer, or solver

MY_REACT_PROMPT_2 = """
You are a math problem-solving agent.

Work carefully and solve the problem step by step.

Use tools whenever they are useful:
- Use add, subtract, multiply, divide, or modular_arithmetic for direct arithmetic.
- Use sympy_solve only for equations involving x.
- Do not use sympy_solve for simplification-only tasks.

Important tool-use rules:
- SymPy expects valid Python-style math syntax.
- Always rewrite implicit multiplication like 3k as 3*k before using a tool.
- Use ** for powers.
- If a tool returns an error, do not repeat the same call. Rewrite the expression and try again.

Reason briefly before each tool call.
After each tool result, either make one new useful tool call or submit the answer.
Do not loop.

When you are ready, submit only the final mathematical answer, with no explanation.
"""

# Добавим явный тул для упрощения

@tool
def sympy_simplify():
    async def execute(expression: str) -> str:
        """Simplify a mathematical expression using SymPy.

        Args:
            expression: A mathematical expression as a string in Python-style syntax.
                Use * for multiplication and ** for powers.
        """
        try:
            expr = sp.sympify(expression.strip())
            return str(sp.simplify(expr))
        except Exception as e:
            return f"Error: {e}"
    return execute

ALL_TOOLS_V2 = [
    add(),
    subtract(),
    multiply(),
    divide(),
    modular_arithmetic(),
    sympy_solve(),
    sympy_simplify(),
]

log_attempt_2 = eval(
    Task(
        dataset=DEV_SET,
        solver=react(
            prompt=MY_REACT_PROMPT_2,
            tools=ALL_TOOLS_V2,
            attempts=1,
        ),
        scorer=MATH_SCORER,
        message_limit=MAX_MESSAGES,
    ),
    model=SMALL_MODEL,
    limit=EVAL_LIMIT,
    attempt_timeout=300,
    max_retries=3,
)[0]

description_2 = "Attempt 2: improved prompt with tool-use guidelines + added sympy_simplify tool"
print_results(description_2, log_attempt_2)
DEV_RUNS.append((description_2, log_attempt_2))
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Attempt 2: improved prompt with tool-use guidelines + added sympy_simplify tool   accuracy: 23%
# ============================================================
#   [C] # 1  msgs= 5  target=                  10  GRADE: C
#   [I] # 2  msgs=20  target=                  47  GRADE: I
#   [C] # 3  msgs= 5  target=                2k+2  GRADE: C
#   [I] # 4  msgs= 5  target=                   2  GRADE: I
#   [I] # 5  msgs=19  target=                   5  GRADE: I
#   [C] # 6  msgs= 5  target=          (a+5)(b+2)  GRADE: C
#   [I] # 7  msgs=15  target=                 550  GRADE: I
#   [C] # 8  msgs=11  target=                   2  GRADE: C
#   [I] # 9  msgs=15  target=                   0  GRADE: I
#   [I] #10  msgs=11  target=                   1  GRADE: I
#   [I] #11  msgs=20  target=                   3  GRADE: I
#   [C] #12  msgs=15  target=         \frac{3}{2}  GRADE: C
#   [I] #13  msgs=11  target=                   1  GRADE: I
#   [I] #14  msgs=20  target=                   4  GRADE: I
#   [C] #15  msgs= 5  target=                  14  GRADE: C
#   [I] #16  msgs=20  target=               26000  GRADE: I
#   [I] #17  msgs=20  target=          \$32,\!348  GRADE: I
#   [I] #18  msgs= 5  target=                  13  GRADE: I
#   [I] #19  msgs= 9  target=                  24  GRADE: I
#   [I] #20  msgs=11  target=                  64  GRADE: I
#   [I] #21  msgs=20  target=                   2  GRADE: I
#   [I] #22  msgs=13  target=            36^\circ  GRADE: I
#   [I] #23  msgs=20  target=        \frac{13}{4}  GRADE: I
#   [I] #24  msgs=20  target=                4005  GRADE: I
#   [C] #25  msgs=14  target=                   4  GRADE: C
#   [I] #26  msgs= 5  target=                 120  GRADE: I
#   [I] #27  msgs=13  target=              4343_6  Grade not found in model output: <|start|>assistant<|channel
#   [I] #28  msgs= 7  target=       \frac{17}{21}  GRADE: I
#   [I] #29  msgs=11  target=                  36  GRADE: I
#   [I] #30  msgs=16  target=                   6  GRADE: I

# %% [markdown]
# По выборочному просмотру логов модель стала лучше справляться с вызовом инструментов. Правда это не дало критического прироста способностей, в целом с математичеким рассуждением модель пока справляется так себе.

# %%
# Затюнемся немного под dev dataset: добавим новые тулы, в промпт few-shot

@tool
def sympy_solve_for():
    async def execute(equation: str, variable: str) -> str:
        """Solve an equation for a given variable using SymPy.

        Args:
            equation: An equation or expression as a string. If it contains "=",
                the tool solves left - right = 0. If there is no "=",
                the expression is treated as equal to zero.
            variable: The variable to solve for, e.g. x, r, n.
        """
        try:
            var = sp.Symbol(variable.strip())

            if "=" in equation:
                left_str, right_str = equation.split("=", 1)
                left_expr = sp.sympify(left_str.strip(), locals={variable: var})
                right_expr = sp.sympify(right_str.strip(), locals={variable: var})
                expr = left_expr - right_expr
            else:
                expr = sp.sympify(equation.strip(), locals={variable: var})

            solutions = sp.solve(expr, var)

            if not solutions:
                return "No solution found."

            return str(solutions)

        except Exception as e:
            return f"Error: {e}"
    return execute


@tool
def gcd_tool():
    async def execute(a: int, b: int) -> str:
        """Compute the greatest common divisor of two integers.

        Args:
            a: First integer.
            b: Second integer.
        """
        try:
            return str(sp.gcd(int(a), int(b)))
        except Exception as e:
            return f"Error: {e}"
    return execute


ALL_TOOLS_V3 = [
    add(),
    subtract(),
    multiply(),
    divide(),
    modular_arithmetic(),
    sympy_simplify(),
    sympy_solve_for(),
    gcd_tool(),
]

MY_REACT_PROMPT_3 = """
You are a math problem-solving agent.

Work step by step. Use tools whenever helpful.

Tool rules:
- Use add, subtract, multiply, divide, or modular_arithmetic for direct arithmetic.
- Use sympy_simplify to simplify expressions.
- Use sympy_solve_for to solve equations, and specify the correct variable.
- Use gcd_tool only for integer gcd computations.

Formatting rules:
- Rewrite implicit multiplication like 3k as 3*k.
- Use ** for powers.
- Do not send LaTeX commands like \\frac or \\triangle into SymPy tools.
- If a tool returns an error, do not repeat the same call. Rewrite the input first.

Examples:

Example 1
Problem: Find r such that 6*r**2 - 19*r - 7 = 4*r - 3
Reasoning: This is an equation in r, so use sympy_solve_for.
Tool: sympy_solve_for("6*r**2 - 19*r - 7 = 4*r - 3", "r")
Result: [1, 7/2]
Final answer: 1, 7/2

Example 2
Problem: Simplify (-k + 4) + (-2 + 3*k)
Reasoning: This is a simplification task.
Tool: sympy_simplify("(-k + 4) + (-2 + 3*k)")
Result: 2*k + 2
Final answer: 2*k + 2

Example 3
Problem: What is gcd(18, 24)?
Reasoning: This is an integer gcd computation.
Tool: gcd_tool(18, 24)
Result: 6
Final answer: 6

When you are ready, submit only the final mathematical answer, with no explanation.
"""

log_attempt_3 = eval(
    Task(
        dataset=DEV_SET,
        solver=react(
            prompt=MY_REACT_PROMPT_3,
            tools=ALL_TOOLS_V3,
            attempts=1,
        ),
        scorer=MATH_SCORER,
        message_limit=MAX_MESSAGES,
    ),
    model=SMALL_MODEL,
    limit=EVAL_LIMIT,
    attempt_timeout=120,
    max_retries=5,
    max_connections=10,
    retry_on_error=1,   # retry failed sample once
    fail_on_error=False,
    continue_on_fail=True,
    debug_errors=True,
)[0]

description_3 = "Attempt 3: general solve tool + gcd tool + few-shot tool-use examples"
print_results(description_3, log_attempt_3)
DEV_RUNS.append((description_3, log_attempt_3))
# Out:
# Output()
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
# [04/07/26 21:22:43] WARNING  Sample error (id: 13, epoch: 1): RetryError(<Future at 0x258b80d31d0        ]8;id=46542;file://d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\_eval\task\run.py\run.py]8;;\:]8;id=743215;file://d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\_eval\task\run.py#765\765]8;;\
#                              state=finished raised AttemptTimeoutError>)). Sample will be retried.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:116 in __call__             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '120' exceeded.
#
# The above exception was the direct cause of the following exception:
#
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\_eval\task\run.py:989 in task_run_sample      |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\tasks.py:277 in  |
# | __step                                                                                                         |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\_eval\task\run.py:905 in run                  |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\solver\_plan.py:105 in __call__               |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\agent\_as_solver.py:72 in solve               |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\agent\_react.py:210 in execute                |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\agent\_react.py:550 in _agent_generate        |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\agent\_react.py:570 in generate               |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:591 in generate               |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:1046 in _generate             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:193 in async_wrapped        |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:112 in __call__             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:157 in iter                 |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\_utils.py:111 in inner                          |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\__init__.py:414 in exc_check                    |
# +----------------------------------------------------------------------------------------------------------------+
# RetryError: RetryError[<Future at 0x258b80d31d0 state=finished raised AttemptTimeoutError>]
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Attempt 3: general solve tool + gcd tool + few-shot tool-use examples   accuracy: 27%
# ============================================================
#   [I] # 1  msgs=20  target=                  10  GRADE: I
#   [I] # 2  msgs=20  target=                  47  GRADE: I
#   [C] # 3  msgs=11  target=                2k+2  GRADE: C
#   [I] # 4  msgs=14  target=                   2  GRADE: I
#   [I] # 5  msgs= 9  target=                   5  GRADE: I
#   [C] # 6  msgs= 9  target=          (a+5)(b+2)  GRADE: C
#   [I] # 7  msgs= 8  target=                 550  GRADE: I
#   [C] # 8  msgs=15  target=                   2  GRADE: C
#   [C] # 9  msgs= 7  target=                   0  GRADE: C
#   [I] #10  msgs= 9  target=                   1  GRADE: I
#   [I] #11  msgs= 6  target=                   3  GRADE: I
#   [C] #12  msgs= 7  target=         \frac{3}{2}  GRADE: C
#   [I] #13  msgs=16  target=                   1  GRADE: I
#   [I] #14  msgs= 7  target=                   4  GRADE: I
#   [I] #15  msgs= 7  target=                  14  GRADE: I
#   [I] #16  msgs= 5  target=               26000  GRADE: I
#   [I] #17  msgs= 6  target=          \$32,\!348  GRADE: I
#   [I] #18  msgs=13  target=                  13  GRADE: I
#   [I] #19  msgs=15  target=                  24  GRADE: I
#   [I] #20  msgs= 8  target=                  64  GRADE: I
#   [I] #21  msgs= 3  target=                   2  GRADE: I
#   [I] #22  msgs=10  target=            36^\circ  GRADE: I
#   [I] #23  msgs=17  target=        \frac{13}{4}  GRADE: I
#   [C] #24  msgs= 5  target=                4005  GRADE: C
#   [I] #25  msgs= 5  target=                   4  GRADE: I
#   [C] #26  msgs=11  target=                 120  GRADE: C
#   [I] #27  msgs=20  target=              4343_6  GRADE: I
#   [I] #28  msgs=20  target=       \frac{17}{21}  GRADE: I
#   [C] #29  msgs=19  target=                  36  GRADE: C
#   [I] #30  msgs=20  target=                   6  GRADE: I

# %% [markdown]
# Стало ещё немного лучше, но модель всё ещё часто валится на вызове тулов.

# %%
# Попробуем снизить когнитивную нагрузку на модель за счет одного мощного инструмента

from sympy.parsing.sympy_parser import (
    parse_expr,
    standard_transformations,
    implicit_multiplication_application,
    convert_xor,
)

TRANSFORMS = standard_transformations + (
    implicit_multiplication_application,
    convert_xor,
)

def parse_math_expr(expr: str):
    expr = expr.strip()
    return parse_expr(
        expr,
        transformations=TRANSFORMS,
        local_dict={
            "gcd": sp.gcd,
            "mod": sp.Mod,
            "factorial": sp.factorial,
        },
        evaluate=True,
    )


@tool
def calculate():
    async def execute(expression: str) -> str:
        """Evaluate, simplify, or solve a math expression using SymPy.

        Args:
            expression: A mathematical expression as a string.
                Supported uses:
                - arithmetic, e.g. 2 + 3*4
                - modular arithmetic, e.g. mod(1000000, 397)
                - gcd, e.g. gcd(18, 24)
                - factorial, e.g. factorial(6)
                - simplification, e.g. (-k + 4) + (-2 + 3k)
                - equations, e.g. 2*x + 5 = 21

                Notes:
                - Implicit multiplication is allowed: 3k, (a+b)(c+d)
                - ^ is accepted for powers
                - If an equation is given, the tool solves it for the single variable present
        """
        try:
            if "=" in expression:
                left_str, right_str = expression.split("=", 1)
                left_expr = parse_math_expr(left_str)
                right_expr = parse_math_expr(right_str)
                eq_expr = sp.simplify(left_expr - right_expr)

                free_syms = sorted(eq_expr.free_symbols, key=lambda s: s.name)

                if len(free_syms) == 0:
                    # No variable: just evaluate whether both sides are equal
                    return str(sp.simplify(eq_expr))
                elif len(free_syms) == 1:
                    var = free_syms[0]
                    sols = sp.solve(eq_expr, var)
                    if not sols:
                        return "No solution found."
                    if len(sols) == 1:
                        return str(sols[0])
                    return str(sols)
                else:
                    return (
                        "Error: equation has multiple variables. "
                        "Please provide an equation with exactly one variable."
                    )

            expr = parse_math_expr(expression)

            if expr.free_symbols:
                return str(sp.simplify(expr))
            else:
                return str(sp.simplify(expr))

        except Exception as e:
            return f"Error: {e}"
    return execute


MY_REACT_PROMPT_4 = """
You are a math problem-solving agent.

You have one tool: calculate(expression).

Use calculate(expression) whenever useful.
It can:
- compute arithmetic
- simplify symbolic expressions
- solve equations with one variable
- compute gcd, mod, and factorial

Rules:
- Write math in normal Python-style syntax when possible.
- You may use implicit multiplication like 3k or (a+b)(c+d).
- You may use ^ for powers.
- If calculate returns an error, rewrite the expression and try once more.
- Do not loop.

Examples:

Example 1
Problem: Find r such that 6r^2 - 19r - 7 = 4r - 3
Tool: calculate("6r^2 - 19r - 7 = 4r - 3")
Result: [1, 7/2]
Final answer: 1, 7/2

Example 2
Problem: Simplify (-k + 4) + (-2 + 3k)
Tool: calculate("(-k + 4) + (-2 + 3k)")
Result: 2*k + 2
Final answer: 2*k + 2

Example 3
Problem: What is gcd(18, 24)?
Tool: calculate("gcd(18, 24)")
Result: 6
Final answer: 6

When you are ready, submit only the final mathematical answer, with no explanation.
"""


ALL_TOOLS_V4 = [calculate()]

log_attempt_4 = eval(
    Task(
        dataset=DEV_SET,
        solver=react(
            prompt=MY_REACT_PROMPT_4,
            tools=ALL_TOOLS_V4,
            attempts=1,
        ),
        scorer=MATH_SCORER,
        message_limit=MAX_MESSAGES,
    ),
    model=SMALL_MODEL,
    limit=EVAL_LIMIT,
    attempt_timeout=90,
    max_retries=2,
    max_connections=3,
    retry_on_error=1,
    fail_on_error=False,
    continue_on_fail=True,
    debug_errors=True,
)[0]

description_4 = "Attempt 4: single calculate() tool with deterministic SymPy backend"
print_results(description_4, log_attempt_4)
DEV_RUNS.append((description_4, log_attempt_4))
# Out:
# Output()
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '90' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '90' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '90' exceeded.
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:977 in generate               |
# +----------------------------------------------------------------------------------------------------------------+
# AttemptTimeoutError: attempt_timeout '90' exceeded.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ============================================================
#   Attempt 4: single calculate() tool with deterministic SymPy backend   accuracy: 33%
# ============================================================
#   [I] # 1  msgs=11  target=                  10  GRADE: I
#   [I] # 2  msgs=20  target=                  47  GRADE: I
#   [C] # 3  msgs= 5  target=                2k+2  GRADE: C
#   [I] # 4  msgs=14  target=                   2  GRADE: I
#   [I] # 5  msgs=13  target=                   5  GRADE: I
#   [C] # 6  msgs=12  target=          (a+5)(b+2)  GRADE: C
#   [C] # 7  msgs= 8  target=                 550  GRADE: C
#   [C] # 8  msgs= 3  target=                   2  GRADE: C
#   [I] # 9  msgs=13  target=                   0  GRADE: I
#   [I] #10  msgs=11  target=                   1  GRADE: I
#   [I] #11  msgs= 9  target=                   3  GRADE: I
#   [I] #12  msgs= 7  target=         \frac{3}{2}  GRADE: I
#   [I] #13  msgs=20  target=                   1  GRADE: I
#   [C] #14  msgs= 5  target=                   4  GRADE: C
#   [C] #15  msgs= 5  target=                  14  GRADE: C
#   [C] #16  msgs= 7  target=               26000  GRADE: C
#   [I] #17  msgs= 5  target=          \$32,\!348  GRADE: I
#   [I] #18  msgs= 5  target=                  13  GRADE: I
#   [I] #19  msgs= 6  target=                  24  GRADE: I
#   [I] #20  msgs=20  target=                  64  GRADE: I
#   [I] #21  msgs=15  target=                   2  GRADE: I
#   [I] #22  msgs= 5  target=            36^\circ  GRADE: I
#   [I] #23  msgs=13  target=        \frac{13}{4}  GRADE: I
#   [C] #24  msgs=11  target=                4005  GRADE: C
#   [C] #25  msgs=11  target=                   4  GRADE: C
#   [C] #26  msgs=18  target=                 120  GRADE: C
#   [I] #27  msgs=14  target=              4343_6  GRADE: I
#   [I] #28  msgs= 9  target=       \frac{17}{21}  GRADE: I
#   [I] #29  msgs= 8  target=                  36  GRADE: I
#   [I] #30  msgs= 8  target=                   6  GRADE: I

# %% [markdown]
# Да, упрощение интерфеса в пользу одного тула действительно улучшило результат. Думаю на этом мы остановим итерации, вряд ли из нашей llama-3.1-8B мы с помощью скаффолдинга сможем выжать качественно лучший результат.

# %%
print(f"{'Configuration':<40s} {'Dev Accuracy':>12s}")
print("=" * 54)
for description, log in DEV_RUNS:
    acc = get_acc(log)
    print(f"{description:<40s} {acc:>12.0%}")
# Out:
# Configuration                            Dev Accuracy
# ======================================================
# Attempt 1 (baseline)                              97%
# Attempt 1 (llama-3.1-8b-instruct)                 20%
# Attempt 2: improved prompt with tool-use guidelines + added sympy_simplify tool          23%
# Attempt 3: general solve tool + gcd tool + few-shot tool-use examples          27%
# Attempt 4: single calculate() tool with deterministic SymPy backend          33%

# %% [markdown]
# ---
# 1. What modifications did you try? Which had the biggest impact?
# 2. What was the best dev-set accuracy you achieved? What configuration produced it?
# 3. Did any change that you expected to help actually hurt? Why might that be?
# 4. Look at the individual failures. What are the most common error types?
#
# **Your answer:**
#
# 1. baseline + несколько попыток улучшить tools и следование модели формату вызова, например few-shot examples. Хоть llama-3.1-8b-instruct и поддерживает tools, с корректным вызовом у неё большие сложности.
# 2. Упрощение интерфейса tools (до одного инструмента) и максимальный вынос логики за пределы рассуждения модели.
# 3. В целом не было такого, но ожидал немного больших улучшений.
# 4. Ошибки вызова инструментов. Плюс на части задач модели судя по всему не хватает capabilities в части математического reasoning.

# %% [markdown]
# ## 8. Test-Set Evaluation
#
# You've iterated on the dev set and found your best configuration. Now it's time for the
# moment of truth: evaluating on the held-out test set.
#
# > **Run this section only once**, with your best configuration. Re-running and picking
# > the best result would be "test-set contamination" — the same as peeking at a test set
# > in ML.
#
# ## Assignment 5: Run and analyze your best configuration on the test set
#
# Run your best agent configuration on the held-out test set, report accuracy with a 95%
# confidence interval, and break down performance by subject and difficulty level. Note
# anything that stands out.

# %%
def wilson_ci(n_correct, n_total, confidence_level=0.95):
    """Wilson score interval for a binomial proportion."""
    z = norm.ppf(0.5 + confidence_level / 2)
    p_hat = n_correct / n_total
    denom = 1 + z ** 2 / n_total
    centre = (p_hat + z ** 2 / (2 * n_total)) / denom
    margin = z * math.sqrt(
        (p_hat * (1 - p_hat) + z ** 2 / (4 * n_total)) / n_total
    ) / denom
    return max(0, centre - margin), min(1, centre + margin)

# %% [markdown]
# ## Assignment 5.1: Run on the test set
#
# Use your best configuration and run it to evaluate the test set

# %%
BEST_PROMPT = MY_REACT_PROMPT_4
BEST_TOOLS = ALL_TOOLS_V4


log_test = eval(
    Task(
        dataset=TEST_SET,
        solver=react(
            prompt=BEST_PROMPT,
            tools=BEST_TOOLS,
            attempts=1,
        ),
        scorer=MATH_SCORER,
        message_limit=MAX_MESSAGES,
    ),
    model=SMALL_MODEL,
    limit=len(TEST_SET),
    attempt_timeout=90,
    max_retries=2,
    max_connections=3,
    retry_on_error=1,
    fail_on_error=False,
    continue_on_fail=True,
    debug_errors=True,
)[0]

assert log_test.status == "success", f"Test run incomplete: {log_test.status}"

n_test = len(TEST_SET)
n_correct_test = round(get_acc(log_test) * n_test)

lo, hi = wilson_ci(n_correct_test, n_test)
print(f"Test accuracy : {n_correct_test / n_test:.1%}")
print(f"95% Wilson CI : [{lo:.1%}, {hi:.1%}]")
print(f"n = {n_test}")
# Out:
# Output()
# <string>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# <string>:1: SyntaxWarning: 'tuple' object is not callable; perhaps you missed a comma?
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\_eval\task\run.py:1077 in task_run_sample     |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\scorer\_model.py:208 in score                 |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:591 in generate               |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:1046 in _generate             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:193 in async_wrapped        |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:112 in __call__             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:157 in iter                 |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\_utils.py:111 in inner                          |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\__init__.py:393 in <lambda>                     |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\concurrent\futures\_base |
# | .py:449 in result                                                                                              |
# |                                                                                                                |
# |   446                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:                                   |
# |   447                     raise CancelledError()                                                               |
# |   448                 elif self._state == FINISHED:                                                            |
# | > 449                     return self.__get_result()                                                           |
# |   450                                                                                                          |
# |   451                 self._condition.wait(timeout)                                                            |
# |   452                                                                                                          |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\concurrent\futures\_base |
# | .py:401 in __get_result                                                                                        |
# |                                                                                                                |
# |   398     def __get_result(self):                                                                              |
# |   399         if self._exception:                                                                              |
# |   400             try:                                                                                         |
# | > 401                 raise self._exception                                                                    |
# |   402             finally:                                                                                     |
# |   403                 # Break a reference cycle with the exception in self._exception                          |
# |   404                 self = None                                                                              |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\tenacity\asyncio\__init__.py:116 in __call__             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_model.py:967 in generate               |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_providers\openai_compatible.py:218 in  |
# | generate                                                                                                       |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_providers\openai_compatible.py:262 in  |
# | _generate_completion                                                                                           |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:2714 in |
# | create                                                                                                         |
# |                                                                                                                |
# |   2711         timeout: float | httpx.Timeout | None | NotGiven = not_given,                                   |
# |   2712     ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:                                             |
# |   2713         validate_response_format(response_format)                                                       |
# | > 2714         return await self._post(                                                                        |
# |   2715             "/chat/completions",                                                                        |
# |   2716             body=await async_maybe_transform(                                                           |
# |   2717                 {                                                                                       |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\openai\_base_client.py:1884 in post                      |
# |                                                                                                                |
# |   1881         opts = FinalRequestOptions.construct(                                                           |
# |   1882             method="post", url=path, json_data=body, content=content, files=await async_                |
# |   1883         )                                                                                               |
# | > 1884         return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)                  |
# |   1885                                                                                                         |
# |   1886     async def patch(                                                                                    |
# |   1887         self,                                                                                           |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\openai\_base_client.py:1604 in request                   |
# |                                                                                                                |
# |   1601                                                                                                         |
# |   1602             response = None                                                                             |
# |   1603             try:                                                                                        |
# | > 1604                 response = await self._client.send(                                                     |
# |   1605                     request,                                                                            |
# |   1606                     stream=stream or self._should_stream_response_body(request=request),                |
# |   1607                     **kwargs,                                                                           |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_client.py:1643 in send                            |
# |                                                                                                                |
# |   1640                                                                                                         |
# |   1641         except BaseException as exc:                                                                    |
# |   1642             await response.aclose()                                                                     |
# | > 1643             raise exc                                                                                   |
# |   1644                                                                                                         |
# |   1645     async def _send_handling_auth(                                                                      |
# |   1646         self,                                                                                           |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_client.py:1637 in send                            |
# |                                                                                                                |
# |   1634         )                                                                                               |
# |   1635         try:                                                                                            |
# |   1636             if not stream:                                                                              |
# | > 1637                 await response.aread()                                                                  |
# |   1638                                                                                                         |
# |   1639             return response                                                                             |
# |   1640                                                                                                         |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_models.py:979 in aread                            |
# |                                                                                                                |
# |    976         Read and return the response content.                                                           |
# |    977         """                                                                                             |
# |    978         if not hasattr(self, "_content"):                                                               |
# | >  979             self._content = b"".join([part async for part in self.aiter_bytes()])                       |
# |    980         return self._content                                                                            |
# |    981                                                                                                         |
# |    982     async def aiter_bytes(                                                                              |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_models.py:979 in <listcomp>                       |
# |                                                                                                                |
# |    976         Read and return the response content.                                                           |
# |    977         """                                                                                             |
# |    978         if not hasattr(self, "_content"):                                                               |
# | >  979             self._content = b"".join([part async for part in self.aiter_bytes()])                       |
# |    980         return self._content                                                                            |
# |    981                                                                                                         |
# |    982     async def aiter_bytes(                                                                              |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_models.py:997 in aiter_bytes                      |
# |                                                                                                                |
# |    994             decoder = self._get_content_decoder()                                                       |
# |    995             chunker = ByteChunker(chunk_size=chunk_size)                                                |
# |    996             with request_context(request=self._request):                                                |
# | >  997                 async for raw_bytes in self.aiter_raw():                                                |
# |    998                     decoded = decoder.decode(raw_bytes)                                                 |
# |    999                     for chunk in chunker.decode(decoded):                                               |
# |   1000                         yield chunk                                                                     |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_models.py:1055 in aiter_raw                       |
# |                                                                                                                |
# |   1052         chunker = ByteChunker(chunk_size=chunk_size)                                                    |
# |   1053                                                                                                         |
# |   1054         with request_context(request=self._request):                                                    |
# | > 1055             async for raw_stream_bytes in self.stream:                                                  |
# |   1056                 self._num_bytes_downloaded += len(raw_stream_bytes)                                     |
# |   1057                 for chunk in chunker.decode(raw_stream_bytes):                                          |
# |   1058                     yield chunk                                                                         |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_client.py:176 in __aiter__                        |
# |                                                                                                                |
# |    173         self._start = start                                                                             |
# |    174                                                                                                         |
# |    175     async def __aiter__(self) -> typing.AsyncIterator[bytes]:                                           |
# | >  176         async for chunk in self._stream:                                                                |
# |    177             yield chunk                                                                                 |
# |    178                                                                                                         |
# |    179     async def aclose(self) -> None:                                                                     |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpx\_transports\default.py:271 in __aiter__            |
# |                                                                                                                |
# |   268                                                                                                          |
# |   269     async def __aiter__(self) -> typing.AsyncIterator[bytes]:                                            |
# |   270         with map_httpcore_exceptions():                                                                  |
# | > 271             async for part in self._httpcore_stream:                                                     |
# |   272                 yield part                                                                               |
# |   273                                                                                                          |
# |   274     async def aclose(self) -> None:                                                                      |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:407 in __aiter__      |
# |                                                                                                                |
# |   404                 yield part                                                                               |
# |   405         except BaseException as exc:                                                                     |
# |   406             await self.aclose()                                                                          |
# | > 407             raise exc from None                                                                          |
# |   408                                                                                                          |
# |   409     async def aclose(self) -> None:                                                                      |
# |   410         if not self._closed:                                                                             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpcore\_async\connection_pool.py:403 in __aiter__      |
# |                                                                                                                |
# |   400                                                                                                          |
# |   401     async def __aiter__(self) -> typing.AsyncIterator[bytes]:                                            |
# |   402         try:                                                                                             |
# | > 403             async for part in self._stream:                                                              |
# |   404                 yield part                                                                               |
# |   405         except BaseException as exc:                                                                     |
# |   406             await self.aclose()                                                                          |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpcore\_async\http11.py:342 in __aiter__               |
# |                                                                                                                |
# |   339             # before raising that exception.                                                             |
# |   340             with AsyncShieldCancellation():                                                              |
# |   341                 await self.aclose()                                                                      |
# | > 342             raise exc                                                                                    |
# |   343                                                                                                          |
# |   344     async def aclose(self) -> None:                                                                      |
# |   345         if not self._closed:                                                                             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpcore\_async\http11.py:334 in __aiter__               |
# |                                                                                                                |
# |   331         kwargs = {"request": self._request}                                                              |
# |   332         try:                                                                                             |
# |   333             async with Trace("receive_response_body", logger, self._request, kwargs):                    |
# | > 334                 async for chunk in self._connection._receive_response_body(**kwargs):                    |
# |   335                     yield chunk                                                                          |
# |   336         except BaseException as exc:                                                                     |
# |   337             # If we get an exception while streaming the response,                                       |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpcore\_async\http11.py:203 in _receive_response_body  |
# |                                                                                                                |
# |   200         timeout = timeouts.get("read", None)                                                             |
# |   201                                                                                                          |
# |   202         while True:                                                                                      |
# | > 203             event = await self._receive_event(timeout=timeout)                                           |
# |   204             if isinstance(event, h11.Data):                                                              |
# |   205                 yield bytes(event.data)                                                                  |
# |   206             elif isinstance(event, (h11.EndOfMessage, h11.PAUSED)):                                      |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpcore\_async\http11.py:217 in _receive_event          |
# |                                                                                                                |
# |   214                 event = self._h11_state.next_event()                                                     |
# |   215                                                                                                          |
# |   216             if event is h11.NEED_DATA:                                                                   |
# | > 217                 data = await self._network_stream.read(                                                  |
# |   218                     self.READ_NUM_BYTES, timeout=timeout                                                 |
# |   219                 )                                                                                        |
# |   220                                                                                                          |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\httpcore\_backends\anyio.py:35 in read                   |
# |                                                                                                                |
# |    32         with map_exceptions(exc_map):                                                                    |
# |    33             with anyio.fail_after(timeout):                                                              |
# |    34                 try:                                                                                     |
# | >  35                     return await self._stream.receive(max_bytes=max_bytes)                               |
# |    36                 except anyio.EndOfStream:  # pragma: nocover                                             |
# |    37                     return b""                                                                           |
# |    38                                                                                                          |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\anyio\streams\tls.py:244 in receive                      |
# |                                                                                                                |
# |   241         await self.transport_stream.aclose()                                                             |
# |   242                                                                                                          |
# |   243     async def receive(self, max_bytes: int = 65536) -> bytes:                                            |
# | > 244         data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)                       |
# |   245         if not data:                                                                                     |
# |   246             raise EndOfStream                                                                            |
# |   247                                                                                                          |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\anyio\streams\tls.py:187 in _call_sslobject_method       |
# |                                                                                                                |
# |   184                     if self._write_bio.pending:                                                          |
# |   185                         await self.transport_stream.send(self._write_bio.read())                         |
# |   186                                                                                                          |
# | > 187                     data = await self.transport_stream.receive()                                         |
# |   188                 except EndOfStream:                                                                      |
# |   189                     self._read_bio.write_eof()                                                           |
# |   190                 except OSError as exc:                                                                   |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\anyio\_backends\_asyncio.py:1269 in receive              |
# |                                                                                                                |
# |   1266                 and not self._protocol.is_at_eof                                                        |
# |   1267             ):                                                                                          |
# |   1268                 self._transport.resume_reading()                                                        |
# | > 1269                 await self._protocol.read_event.wait()                                                  |
# |   1270                 self._transport.pause_reading()                                                         |
# |   1271             else:                                                                                       |
# |   1272                 await AsyncIOBackend.checkpoint()                                                       |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\locks.py:213 in  |
# | wait                                                                                                           |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\futures.py:287   |
# | in __await__                                                                                                   |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\tasks.py:349 in  |
# | __wakeup                                                                                                       |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\futures.py:198   |
# | in result                                                                                                      |
# +----------------------------------------------------------------------------------------------------------------+
# CancelledError: Cancelled via cancel scope 258bb2d4350 by <Task cancelling name='Task-6875'
# coro=<run_coroutine.<locals>._run_with_async_filesystem() running at
# d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\_util\_async.py:121>>
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py:2849 in _tsolve                 |
# |                                                                                                                |
# |   2846                 poly = lhs.as_poly()                                                                    |
# |   2847                 g = _filtered_gens(poly, sym)                                                           |
# |   2848                 _eq = lhs - rhs                                                                         |
# | > 2849                 sols = _solve_lambert(_eq, sym, g)                                                      |
# |   2850                 # use a simplified form if it satisfies eq                                              |
# |   2851                 # and has fewer operations                                                              |
# |   2852                 for n, s in enumerate(sols):                                                            |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\bivariate.py:411 in _solve_lambert         |
# |                                                                                                                |
# |   408                 soln = _lambert(expand_log(diff), symbol)                                                |
# |   409                                                                                                          |
# |   410     if not soln:                                                                                         |
# | > 411         raise NotImplementedError('%s does not appear to have a solution in '                            |
# |   412             'terms of LambertW' % f)                                                                     |
# |   413                                                                                                          |
# |   414     return list(ordered(soln))                                                                           |
# +----------------------------------------------------------------------------------------------------------------+
# NotImplementedError: -10**x + 10000*(x + 1) does not appear to have a solution in terms of LambertW
#
# During handling of the above exception, another exception occurred:
#
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\assumptions.py:499 in getit                   |
# |                                                                                                                |
# |   496                                                                                                          |
# |   497     def getit(self):                                                                                     |
# |   498         try:                                                                                             |
# | > 499             return self._assumptions[fact]                                                               |
# |   500         except KeyError:                                                                                 |
# |   501             if self._assumptions is self.default_assumptions:                                            |
# |   502                 self._assumptions = self.default_assumptions.copy()                                      |
# +----------------------------------------------------------------------------------------------------------------+
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# +-------------------------------------- Traceback (most recent call last) ---------------------------------------+
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\nest_asyncio2.py:72 in run                               |
# |                                                                                                                |
# |    69         loop.set_debug(debug)                                                                            |
# |    70         task = asyncio.ensure_future(main)                                                               |
# |    71         try:                                                                                             |
# | >  72             return loop.run_until_complete(task)                                                         |
# |    73         finally:                                                                                         |
# |    74             if not task.done():                                                                          |
# |    75                 task.cancel()                                                                            |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\nest_asyncio2.py:212 in run_until_complete               |
# |                                                                                                                |
# |   209             if f is not future:                                                                          |
# |   210                 f._log_destroy_pending = False                                                           |
# |   211             while not f.done():                                                                          |
# | > 212                 self._run_once()                                                                         |
# |   213                 if self._stopping:                                                                       |
# |   214                     break                                                                                |
# |   215             if not f.done():                                                                             |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\nest_asyncio2.py:272 in _run_once                        |
# |                                                                                                                |
# |   269                         curr_task = None                                                                 |
# |   270                                                                                                          |
# |   271                 try:                                                                                     |
# | > 272                     handle._run()                                                                        |
# |   273                 finally:                                                                                 |
# |   274                     # restore the current task                                                           |
# |   275                     if curr_task is not None:                                                            |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\events.py:84 in  |
# | _run                                                                                                           |
# |                                                                                                                |
# | C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\tasks.py:277 in  |
# | __step                                                                                                         |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_call_tools.py:164 in call_tool_task    |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_call_tools.py:454 in call_tool         |
# |                                                                                                                |
# | in execute:63                                                                                                  |
# |                                                                                                                |
# |    60                     return str(sp.simplify(eq_expr))                                                     |
# |    61                 elif len(free_syms) == 1:                                                                |
# |    62                     var = free_syms[0]                                                                   |
# | >  63                     sols = sp.solve(eq_expr, var)                                                        |
# |    64                     if not sols:                                                                         |
# |    65                         return "No solution found."                                                      |
# |    66                     if len(sols) == 1:                                                                   |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py:1168 in solve                   |
# |                                                                                                                |
# |   1165         if len(symbols) != 1:                                                                           |
# |   1166             solution = _solve_undetermined(f[0], symbols, flags)                                        |
# |   1167         if not solution:                                                                                |
# | > 1168             solution = _solve(f[0], *symbols, **flags)                                                  |
# |   1169     else:                                                                                               |
# |   1170         linear, solution = _solve_system(f, symbols, **flags)                                           |
# |   1171     assert type(solution) is list                                                                       |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py:1714 in _solve                  |
# |                                                                                                                |
# |   1711     if result is False:                                                                                 |
# |   1712         flags.pop('tsolve', None)  # allow tsolve to be used on next pass                               |
# |   1713         try:                                                                                            |
# | > 1714             soln = _tsolve(f_num, symbol, **flags)                                                      |
# |   1715             if soln is not None:                                                                        |
# |   1716                 result = [{symbol: v} for v in soln]                                                    |
# |   1717         except PolynomialError:                                                                         |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py:2686 in _tsolve                 |
# |                                                                                                                |
# |   2683             # to try get powers in standard form for better factoring                                   |
# |   2684             f = factor(powdenest(lhs - rhs))                                                            |
# |   2685             if f.is_Mul:                                                                                |
# | > 2686                 return _vsolve(f, sym, **flags)                                                         |
# |   2687             if rhs:                                                                                     |
# |   2688                 f = logcombine(lhs, force=flags.get('force', True))                                     |
# |   2689                 if f.count(log) != lhs.count(log):                                                      |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py:2638 in _vsolve                 |
# |                                                                                                                |
# |   2635                                                                                                         |
# |   2636 def _vsolve(e, s, **flags):                                                                             |
# |   2637     """return list of scalar values for the solution of e for symbol s"""                               |
# | > 2638     return [i[s] for i in _solve(e, s, **flags)]                                                        |
# |   2639                                                                                                         |
# |   2640                                                                                                         |
# |   2641 def _tsolve(eq, sym, **flags):                                                                          |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py:1392 in _solve                  |
# |                                                                                                                |
# |   1389             if m in {S.NegativeInfinity, S.ComplexInfinity, S.Infinity}:                                |
# |   1390                 result = set()                                                                          |
# |   1391                 break                                                                                   |
# | > 1392             soln = _vsolve(m, symbol, **flags)                                                          |
# |   1393             result.update(set(soln))                                                                    |
# |   1394         result = [{symbol: v} for v in result]                                                          |
# |   1395         if check:                                                                                       |
# |                                                                                                                |
# | d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py:2638 in _vsolve                 |
# |                                                                                                                |
# |   2635                                                                                                         |
# |   2636 def _vsolve(e, s, **flags):                                                                             |
# ...
#               |     return loop.run_until_complete(task)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\nest_asyncio2.py", line 212, in run_until_complete
#               |     self._run_once()
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\nest_asyncio2.py", line 272, in _run_once
#               |     handle._run()
#               |   File "C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\events.py", line 84, in _run
#               |     self._context.run(self._callback, *self._args)
#               |   File "C:\Users\yuri.zinyakov\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\asyncio\tasks.py", line 277, in __step
#               |     result = coro.send(None)
#               |              ^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_call_tools.py", line 164, in call_tool_task
#               |     result, messages, output, agent, agent_span_id = await call_tool(
#               |                                                      ^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\inspect_ai\model\_call_tools.py", line 454, in call_tool
#               |     result: ToolResult = await tool_def.tool(**arguments)
#               |                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "C:\Users\yuri.zinyakov\AppData\Local\Temp\ipykernel_13700\2635318641.py", line 63, in execute
#               |     sols = sp.solve(eq_expr, var)
#               |            ^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 1168, in solve
#               |     solution = _solve(f[0], *symbols, **flags)
#               |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 1714, in _solve
#               |     soln = _tsolve(f_num, symbol, **flags)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 2686, in _tsolve
#               |     return _vsolve(f, sym, **flags)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 2638, in _vsolve
#               |     return [i[s] for i in _solve(e, s, **flags)]
#               |                           ^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 1392, in _solve
#               |     soln = _vsolve(m, symbol, **flags)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 2638, in _vsolve
#               |     return [i[s] for i in _solve(e, s, **flags)]
#               |                           ^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 1714, in _solve
#               |     soln = _tsolve(f_num, symbol, **flags)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 2870, in _tsolve
#               |     inversion = _tsolve(g - u, sym, **flags)
#               |                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 2892, in _tsolve
#               |     soln = _vsolve(pos, u, **flags)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 2638, in _vsolve
#               |     return [i[s] for i in _solve(e, s, **flags)]
#               |                           ^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 1727, in _solve
#               |     result = [{k: d[k].simplify() for k in d} for d in result]
#               |              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 1727, in <listcomp>
#               |     result = [{k: d[k].simplify() for k in d} for d in result]
#               |               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\solvers\solvers.py", line 1727, in <dictcomp>
#               |     result = [{k: d[k].simplify() for k in d} for d in result]
#               |                   ^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1956, in simplify
#               |     return simplify(self, **kwargs)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\simplify.py", line 630, in simplify
#               |     expr = expr.replace(
#               |            ^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1797, in replace
#               |     rv = walk(self, rec_replace)
#               |          ^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1772, in walk
#               |     newargs = tuple([walk(a, F) for a in args])
#               |                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1772, in <listcomp>
#               |     newargs = tuple([walk(a, F) for a in args])
#               |                      ^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1772, in walk
#               |     newargs = tuple([walk(a, F) for a in args])
#               |                     ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1772, in <listcomp>
#               |     newargs = tuple([walk(a, F) for a in args])
#               |                      ^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1782, in walk
#               |     rv = F(rv)
#               |          ^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1790, in rec_replace
#               |     v = _value(expr, result)
#               |         ^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\basic.py", line 1756, in <lambda>
#               |     _value = lambda expr, result: value(expr)
#               |                                   ^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\simplify.py", line 638, in <lambda>
#               |     lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#               |                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\simplify.py", line 638, in <listcomp>
#               |     lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#               |                        ^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\simplify.py", line 713, in simplify
#               |     expr = trigsimp(expr, deep=True)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\trigsimp.py", line 564, in trigsimp
#               |     expr_simplified = trigsimpfunc(expr)
#               |                       ^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\trigsimp.py", line 557, in <lambda>
#               |     'matching': (lambda x: futrig(x)),
#               |                            ^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\trigsimp.py", line 1158, in futrig
#               |     e = bottom_up(e, _futrig)
#               |         ^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\traversal.py", line 234, in bottom_up
#               |     args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#               |                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\traversal.py", line 234, in <listcomp>
#               |     args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#               |                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\traversal.py", line 234, in bottom_up
#               |     args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#               |                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\traversal.py", line 234, in <listcomp>
#               |     args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#               |                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\traversal.py", line 237, in bottom_up
#               |     rv = F(rv)
#               |          ^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\trigsimp.py", line 1225, in _futrig
#               |     e = greedy(tree, objective=Lops)(e)
#               |         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\strategies\core.py", line 150, in minrule
#               |     return min([rule(expr) for rule in rules], key=objective)
#               |                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\strategies\core.py", line 150, in <listcomp>
#               |     return min([rule(expr) for rule in rules], key=objective)
#               |                 ^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\strategies\core.py", line 64, in chain_rl
#               |     expr = rule(expr)
#               |            ^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\trigsimp.py", line 1202, in <lambda>
#               |     lambda x: _eapply(factor, x, trigs),
#               |               ^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\simplify\trigsimp.py", line 1249, in _eapply
#               |     return func(e)
#               |            ^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\polys\polytools.py", line 6735, in factor
#               |     return _generic_factor(f, gens, args, method='factor')
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\polys\polytools.py", line 6416, in _generic_factor
#               |     return _symbolic_factor(sympify(expr), opt, method)
#               |            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\polys\polytools.py", line 6356, in _symbolic_factor
#               |     coeff, factors = _symbolic_factor_list(together(expr, fraction=opt['fraction']), opt, method)
#               |                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\polys\polytools.py", line 6312, in _symbolic_factor_list
#               |     poly, _ = _poly_from_expr(base, opt)
#               |               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\polys\polytools.py", line 4660, in _poly_from_expr
#               |     expr = expr.expand()
#               |            ^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\cache.py", line 72, in wrapper
#               |     retval = cfunc(*args, **kwargs)
#               |              ^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\expr.py", line 3704, in expand
#               |     expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#               |                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\expr.py", line 3635, in _expand_hint
#               |     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#               |                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\expr.py", line 3635, in _expand_hint
#               |     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#               |                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\expr.py", line 3635, in _expand_hint
#               |     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#               |                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\expr.py", line 3643, in _expand_hint
#               |     newexpr = getattr(expr, hint)(**hints)
#               |               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\mul.py", line 969, in _eval_expand_mul
#               |     t = self.func(plain, term)
#               |         ^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\cache.py", line 72, in wrapper
#               |     retval = cfunc(*args, **kwargs)
#               |              ^^^^^^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\operations.py", line 108, in __new__
#               |     c_part, nc_part, order_symbols = cls.flatten(args)
#               |                                      ^^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\mul.py", line 703, in flatten
#               |     elif coeff.is_zero:
#               |          ^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\assumptions.py", line 503, in getit
#               |     return _ask(fact, self)
#               |            ^^^^^^^^^^^^^^^^
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\assumptions.py", line 566, in _ask
#               |     assumptions.deduce_all_facts(((fact_i, fact_i_value),))
#               |   File "d:\AI_Safety_and_Evals_Course\.venv\Lib\site-packages\sympy\core\facts.py", line None, in deduce_all_facts
#               | KeyboardInterrupt
#               +------------------------------------

# %%
# Не знаю только ли мне так везёт при работе с Inspect AI, но во всех ноутбуках курса ведёт себя дико нестабильно в связке с Open Router
from inspect_ai import task, Task, eval_retry

@task(name="task")
def retry_test_task():
    return Task(
        dataset=TEST_SET,
        solver=react(
            prompt=BEST_PROMPT,
            tools=BEST_TOOLS,
            attempts=1,
        ),
        scorer=MATH_SCORER,
        message_limit=MAX_MESSAGES, 
    )

log_path = "logs/2026-04-07T20-09-17-00-00_task_RYR8MvmAqvKRLQQsysfdQg.eval"


log_test = eval_retry(
    log_path,
    attempt_timeout=90,
    max_retries=1,
    max_connections=10,
    retry_on_error=1,
    fail_on_error=False,
    continue_on_fail=True,
    debug_errors=True,
)[0]
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
assert log_test.status == "success", f"Test run incomplete: {log_test.status}"

n_test = len(TEST_SET)
n_correct_test = round(get_acc(log_test) * n_test)

lo, hi = wilson_ci(n_correct_test, n_test)
print(f"Test accuracy : {n_correct_test / n_test:.1%}")
print(f"95% Wilson CI : [{lo:.1%}, {hi:.1%}]")
print(f"n = {n_test}")
# Out:
# Test accuracy : 26.7%
# 95% Wilson CI : [22.3%, 31.8%]
# n = 329

# %% [markdown]
# ## Assignment 5.2: Breakdown by subject and difficulty level
#
# There aren't enough samples per category to draw firm conclusions — that's fine.
# Just see if anything stands out.
#
# Iterate over logs and produce **two separate tables**: one grouped
# by subject, one by difficulty level.
#
# Your output should look like this:
#
# **By subject:**
#
# | Subject | Correct | Total | Acc |
# |---|---:|---:|---:|
# | Algebra | 1 | 10 | 10% |
# | Precalculus | 3 | 6 | 50% |
# | ... | | | |
#
# **By level:**
#
# | Level | Correct | Total | Acc |
# |---|---:|---:|---:|
# | 1 | 4 | 5 | 80% |
# | 2 | 3 | 6 | 50% |
# | ... | | | |
#
# The actual numbers will appear in the cell below.

# %%
subject_stats = defaultdict(lambda: [0, 0])
level_stats = defaultdict(lambda: [0, 0])

for sample in log_test.samples:
    sc = _first_score(sample)
    correct = 1 if sc.value == "C" else 0
    subj = sample.metadata.get("subject", "unknown")
    lvl = sample.metadata.get("level", 0)
    subject_stats[subj][0] += correct
    subject_stats[subj][1] += 1
    level_stats[lvl][0] += correct
    level_stats[lvl][1] += 1

print(f"{'Subject':<30s} {'Correct':>7s} {'Total':>5s} {'Acc':>6s}")
print("-" * 50)
for subj in sorted(subject_stats):
    c, t = subject_stats[subj]
    print(f"{subj:<30s} {c:>7d} {t:>5d} {c/t:>6.0%}")

print()
print(f"{'Level':<30s} {'Correct':>7s} {'Total':>5s} {'Acc':>6s}")
print("-" * 50)
for lvl in sorted(level_stats):
    c, t = level_stats[lvl]
    print(f"Level {lvl:<24d} {c:>7d} {t:>5d} {c/t:>6.0%}")
# Out:
# Subject                        Correct Total    Acc
# --------------------------------------------------
# Algebra                             32   113    28%
# Intermediate Algebra                13    85    15%
# Number Theory                       16    58    28%
# Prealgebra                          27    73    37%
#
# Level                          Correct Total    Acc
# --------------------------------------------------
# Level 1                             20    32    62%
# Level 2                             24    59    41%
# Level 3                             17    63    27%
# Level 4                             16    85    19%
# Level 5                             11    90    12%

# %% [markdown]
# **Your results:**
#
# Fill in the tables once you've run the cell above.
#
# **By subject:**
#
# | Subject              | Correct | Total | Acc |
# | -------------------- | ------: | ----: | --: |
# | Algebra              |      32 |   113 | 28% |
# | Intermediate Algebra |      13 |    85 | 15% |
# | Number Theory        |      16 |    58 | 28% |
# | Prealgebra           |      27 |    73 | 37% |
#
#
# **By difficulty level:**
#
# | Level | Correct | Total | Acc |
# | ----- | ------: | ----: | --: |
# | 1     |      20 |    32 | 62% |
# | 2     |      24 |    59 | 41% |
# | 3     |      17 |    63 | 27% |
# | 4     |      16 |    85 | 19% |
# | 5     |      11 |    90 | 12% |

# %% [markdown]
# ## Final comparison: dev vs test

# %%
print(f"{'Configuration':<30s} {'Dev Acc':>8s}  {'Test Acc':>8s}")
print("=" * 50)
for name, log in DEV_RUNS:
    acc = get_acc(log)
    print(f"{name:<30s} {acc:>8.0%}  {'--':>8s}")
print(f"{'best agent (TEST)':<30s} {'--':>8s}  {n_correct_test / n_test:>8.1%}")
print(f"\n95% CI on test: [{lo:.1%}, {hi:.1%}]")
# Out:
# Configuration                   Dev Acc  Test Acc
# ==================================================
# Attempt 1 (baseline)                97%        --
# Attempt 1 (llama-3.1-8b-instruct)      20%        --
# Attempt 2: improved prompt with tool-use guidelines + added sympy_simplify tool      23%        --
# Attempt 3: general solve tool + gcd tool + few-shot tool-use examples      27%        --
# Attempt 4: single calculate() tool with deterministic SymPy backend      33%        --
# best agent (TEST)                    --     26.7%
#
# 95% CI on test: [22.3%, 31.8%]

# %% [markdown]
# ---
# 1. How does the test accuracy compare to the dev accuracy? If there's a gap,
#    what might explain it?
# 2. Which subjects and difficulty levels does the agent handle best? Worst?
# 3. Look at the confidence interval. Is it narrow enough to be useful, or would
#    you want more test samples?
# 4. If you were to improve this agent further, where would you focus?
#
# **Your answer:**
#
# 1. Да, есть разница. Понятно что мы тюнили агента на dev и за счет этого как бы немного переобучились под конретный сет вопросов. Так что небольшая просадка на тесте ожидаема.
# 2. Предсказуемо, чем проще задачи тем выше процент успеха. По областям наилучшая доля у Prealgebra.
# 3. Он полезен, т.к. дает неплохое представление о способностях текущей версии агента. Но если нужна тонки сравнения в пределах 10-20%, то конечно нужно больше данных.
# 4. Заменил бы модель, т.к. даже в классе до 10B существуют более современные модели, которые лучше работают с инструментами. Если говорить про текущую версию - всё ещё не идеально следование формату вызова, перевод вопроса в математическое выражение для инструмента. Но не уверен что конкретно в нашем кейсе с llama-3.1-8B-instruct дальнейший scaffolding приведёт к результатам значимо отличающимся от полученных.

# %% [markdown]
# ## Bonus assignment: Error Analysis
#
# Pick 5-10 test samples that the agent got wrong and classify each failure. Here's one
# possible taxonomy — feel free to use your own:
#
# - **Tool misuse:** Called the wrong tool or with wrong arguments
# - **Reasoning error:** Correct tool use but flawed multi-step reasoning
# - **Format error:** Correct answer but wrong format in `submit()`
# - **Inherent difficulty:** Problem requires reasoning beyond the tool set
# - **Grading error:** The agent was actually right but the scorer got it wrong
# - **Other:** Anything that doesn't fit the above
#
# This kind of qualitative error analysis is essential in practice — aggregate metrics
# tell you *how much* the agent struggles, but error analysis tells you *why*.

# %% [markdown]
# If you'd like to explore the logs in code, use the cell below — otherwise just read
# them directly and delete it.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# 1. What was the most common failure mode?
# 2. Which failure modes could be fixed with better prompting vs. better tools
#    vs. a more capable model?
# 3. Did you find any grading errors? What does that imply about using model-graded scoring?
#
# **Your answer:**
